# %% [markdown]
# Introduction/Business Problem
#
# I will compare Toronto and New York as they are both very popular tourist cities. I would like to investigate how similar or dissimilar they are from a tourists' perspective (ie: food, lodgings, tourist spots, etc.). Tourism is very important to local economies, and tourists would care about how attractive NYC or Toronto is compared to each other in deciding where to choose as their next destination. Tourists are my target audience for this presentation as I think they could benefit from the comparison of these two popular cities!
